# %%
import numpy as np

fname_in="./test_cg_smooth_0_in"
fname_out="./test_cg_smooth_0_out"

nx=50
ny=50
nz=50

# Read in the input file and convert to a 3D numpy array by genfromtxt
data_in = np.genfromtxt(fname_in, delimiter='   ', dtype=None)
data_in = data_in.reshape((nx,ny,nz))

# Read in the output file and convert to a 3D numpy array by genfromtxt
data_out = np.genfromtxt(fname_out, delimiter='   ', dtype=None)
data_out = data_out.reshape((nx,ny,nz))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 16
#      14 # Read in the output file and convert to a 3D numpy array by genfromtxt
#      15 data_out = np.genfromtxt(fname_out, delimiter='   ', dtype=None)
# ---> 16 data_out = data_out.reshape((nx,ny,nz))
#
# ValueError: cannot reshape array of size 2500 into shape (50,50,50)

# %%
#plot
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
plt.imshow(data_in[:,:,25], origin='lower', cmap='jet')
plt.colorbar()
plt.title('Input')
plt.subplot(1,2,2)
plt.imshow(data_out[:,:,25], origin='lower', cmap='jet')
plt.colorbar()
plt.title('Output')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 10
#       8 plt.title('Input')
#       9 plt.subplot(1,2,2)
# ---> 10 plt.imshow(data_out[:,:,25], origin='lower', cmap='jet')
#      11 plt.colorbar()
#      12 plt.title('Output')
#
# IndexError: too many indices for array: array is 1-dimensional, but 3 were indexed
