# %%
# load functions for data processing
# %run ../utils/functions_for_data.ipynb

# %%
# 初始合成到时数据文件 synthetic traveltime data in the initial model
fn_syn_init     = "../6_checkerboard_inversion_test/OUTPUT_FILES/OUTPUT_FILES_inv_abs/src_rec_file_step_0000.dat"

# 最终合成到时数据文件 synthetic traveltime data in the initial model
fn_syn_final    = "../6_checkerboard_inversion_test/OUTPUT_FILES/OUTPUT_FILES_inv_abs/src_rec_file_step_0039.dat"

# 观测到时数据文件 synthetic traveltime data in the initial model
fn_obs          = "../6_checkerboard_inversion_test/OUTPUT_FILES/OUTPUT_FILES_signal/src_rec_file_forward.dat"

# 残差直方图的范围和条带个数 range of the residual histogram and number of bins
range_l = -0.3
range_r = 0.3
Nbar = 20

fig_residual_histogram(fn_syn_init,fn_syn_final,fn_obs,range_l,range_r,Nbar)
# Out:
# residual for Crust1.0 is:  mean:  0.019019619706136585 sd:  0.10808992415929759
# residual for 1d inversion is:  mean:  0.00017839239412277533 sd:  0.010548764167307672
